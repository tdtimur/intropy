# %% [markdown]
# # Bagian III: Data, Struktur Data dan *Control Flow*

# %% [markdown]
# ## 1. Tipe Data

# %% [markdown]
# Masukkan Integer, float, complex, string, boolean

# %% [markdown]
# ## 2. Struktur Data

# %% [markdown]
# ### *List*

# %% [markdown]
# ### *Tuple*

# %% [markdown]
# ### Vektor

# %% [markdown]
# ### Matriks

# %% [markdown]
# ### Tensor

# %% [markdown]
# ## 3. *Control Flow*

# %% [markdown]
# ### `if-then`

# %% [markdown]
# ### `if-else`

# %% [markdown]
# ### Loop `for`

# %% [markdown]
# ### Loop `while`

# %% [markdown]
# ### `Exception`

# %% [markdown]
# ### `Raise-Error`
